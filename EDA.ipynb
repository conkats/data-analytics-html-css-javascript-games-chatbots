# %% [markdown]
# ## Data Analysis with Python

# %% [markdown]
# # Pandas
# Pandas=Palo Data

# %%
import pandas as pd

# %% [markdown]
# # Upload Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.info()
#see number of non-null values
#type of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Data manipulation methods
#
# ## Slicing
# Dataframe is a class

# %%
df.loc[9]#9th row of df
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            42.0
# bill_depth_mm             20.2
# flipper_length_mm        190.0
# body_mass_g             4250.0
# sex                        NaN
# Name: 9, dtype: object

# %%
df.loc[[4]]#9th row but in one row format
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g  sex
# 9       4250.0  NaN

# %%
df.loc[[2,4]]#to select multiple lines
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE

# %% [markdown]
# #Slicing columns

# %%
df.loc[:,'bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
df.loc[:10,['species','bill_length_mm']]
# Out:
#    species  bill_length_mm
# 0   Adelie            39.1
# 1   Adelie            39.5
# 2   Adelie            40.3
# 3   Adelie             NaN
# 4   Adelie            36.7
# 5   Adelie            39.3
# 6   Adelie            38.9
# 7   Adelie            39.2
# 8   Adelie            34.1
# 9   Adelie            42.0
# 10  Adelie            37.8

# %%
#df.loc[row,column]

# %%
df.loc[0:10,['bill_length_mm']]
# Out:
#     bill_length_mm
# 0             39.1
# 1             39.5
# 2             40.3
# 3              NaN
# 4             36.7
# 5             39.3
# 6             38.9
# 7             39.2
# 8             34.1
# 9             42.0
# 10            37.8

# %%
df['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
df.bill_length_mm#method approach same as above for extracting the column
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %% [markdown]
# #Dinstict values

# %%
df['species'].unique()#list of unique possible values for that column
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# #Filter data

# %%
df['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
df['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
df[df['species'] == 'Gentoo'] ##check if the value in the col is Gentoo
#and wrap around around our dataframe to filter with the condition
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 220       4500.0  FEMALE
# 221       5700.0    MALE
# 222       4450.0  FEMALE
# ...

# %%
dream_penguines = df[df['island']=='Dream']
dream_penguines['island'].unique()
# Out:
# array(['Dream'], dtype=object)

# %%
df.describe()#allows summaries, averages, count,standard deviation etc.
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
dream_penguines.head(10)
# Out:
#    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30  Adelie  Dream            39.5           16.7              178.0
# 31  Adelie  Dream            37.2           18.1              178.0
# 32  Adelie  Dream            39.5           17.8              188.0
# 33  Adelie  Dream            40.9           18.9              184.0
# 34  Adelie  Dream            36.4           17.0              195.0
# 35  Adelie  Dream            39.2           21.1              196.0
# 36  Adelie  Dream            38.8           20.0              190.0
# 37  Adelie  Dream            42.2           18.5              180.0
# 38  Adelie  Dream            37.6           19.3              181.0
# 39  Adelie  Dream            39.8           19.1              184.0
#
#     body_mass_g     sex
# 30       3250.0  FEMALE
# 31       3900.0    MALE
# 32       3300.0  FEMALE
# 33       3900.0    MALE
# 34       3325.0  FEMALE
# 35       4150.0    MALE
# 36       3950.0    MALE
# ...

# %% [markdown]
# #Aggregate functions
#
# Summarize multiple rows into a single value/information

# %%
df[df['species'] == 'Gentoo']['body_mass_g'].mean()#find the mean of the body mass after filtering Gentoo species from col species
# Out:
# 5076.016260162602

# %% [markdown]
# #Grouping of Data

# %%
df.groupby('species',as_index = False)['body_mass_g'].mean()#to know the average of all three species (the column that we specify is species)
# Out:
#      species  body_mass_g
# 0     Adelie  3700.662252
# 1  Chinstrap  3733.088235
# 2     Gentoo  5076.016260

# %%
#the spreadsheet equivalent of the .groupby() method would be the pivotable

# %%
df.groupby('sex',as_index = False).size()#count the number of rows using size()
# Out:
#       sex  size
# 0  FEMALE   165
# 1    MALE   168

# %%
df.groupby('species',as_index = False).size()
# Out:
#      species  size
# 0     Adelie   152
# 1  Chinstrap    68
# 2     Gentoo   124

# %%
#examples
df.groupby('island')['bill_depth_mm'].min()
# Out:
# island
# Biscoe       13.1
# Dream        15.5
# Torgersen    15.9
# Name: bill_depth_mm, dtype: float64

# %%
df.groupby('island', as_index='False')['bill_depth_mm'].min()
# Out:
# island
# Biscoe       13.1
# Dream        15.5
# Torgersen    15.9
# Name: bill_depth_mm, dtype: float64

# %%
df.groupby('island', as_index='True')['bill_depth_mm'].min()
# Out:
# island
# Biscoe       13.1
# Dream        15.5
# Torgersen    15.9
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# ##A real example

# %%
import pandas as pd

import seaborn as sns#seaborn is a package that is used for visualisation applications
sns.set_theme()
sns.set(rc={'figure.figsize':(11,7)})
from matplotlib import pyplot as plt # matplotlib is another package visualisation

# %%
df = pd.read_csv('https://raw.githubusercontent.com/boolean-data-analytics/data/main/Superstore%20Data%20S.csv')
df.head()#categorical data, product details
# Out:
#          Order ID  Order Date        Country   Region         State  \
# 0  US-2019-103800  03/01/2019  United States  Central         Texas
# 1  US-2019-112326  04/01/2019  United States  Central      Illinois
# 2  US-2019-112326  04/01/2019  United States  Central      Illinois
# 3  US-2019-112326  04/01/2019  United States  Central      Illinois
# 4  US-2019-141817  05/01/2019  United States     East  Pennsylvania
#
#            City         Category Sub-Category  \
# 0       Houston  Office Supplies        Paper
# 1    Naperville  Office Supplies      Binders
# 2    Naperville  Office Supplies       Labels
# 3    Naperville  Office Supplies      Storage
# 4  Philadelphia  Office Supplies          Art
#
#                                         Product Name  Customer Name  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Darren Powers         2
# 1         GBC Standard Plastic Binding Systems Combs  Phillina Ober         2
# ...

# %%
#book: https://wesmckinney.com/book/numpy-basics.html

# %% [markdown]
# ##Data Analysis

# %%
df['Country'].unique()#check how many countries there are
# Out:
# array(['United States', 'Canada'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10194 non-null  object
#  1   Order Date     10194 non-null  object
#  2   Country        10194 non-null  object
#  3   Region         10194 non-null  object
#  4   State          10194 non-null  object
#  5   City           10194 non-null  object
#  6   Category       10194 non-null  object
#  7   Sub-Category   10194 non-null  object
#  8   Product Name   10194 non-null  object
#  9   Customer Name  10194 non-null  object
#  10  Quantity       10194 non-null  int64
#  11  Sales          10194 non-null  float64
#  12  Discount       10194 non-null  float64
#  13  Profit         10194 non-null  float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
us = df[df['Country'] == 'United States']

# %%
us['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
us.head(3)#row index 1 shows -ve profit, loss?
# Out:
#          Order ID  Order Date        Country   Region     State        City  \
# 0  US-2019-103800  03/01/2019  United States  Central     Texas     Houston
# 1  US-2019-112326  04/01/2019  United States  Central  Illinois  Naperville
# 2  US-2019-112326  04/01/2019  United States  Central  Illinois  Naperville
#
#           Category Sub-Category  \
# 0  Office Supplies        Paper
# 1  Office Supplies      Binders
# 2  Office Supplies       Labels
#
#                                         Product Name  Customer Name  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Darren Powers         2
# 1         GBC Standard Plastic Binding Systems Combs  Phillina Ober         2
# 2                                          Avery 508  Phillina Ober         3
#
#     Sales  Discount  Profit
# 0  16.448       0.2  5.5512
# 1   3.540       0.8 -5.4870
# 2  11.784       0.2  4.2717

# %%
us_cat_profit = us.groupby('Category', as_index=False)['Profit'].sum().sort_values('Profit',ascending=False)#groupy Category by Profit sum and sort by profit in ascending order i.e highest Profit at the top
us_cat_profit
plt.title("Profit by Category")
sns.barplot(x='Category', y ='Profit', data=us_cat_profit, color='grey')
plt.show()

# %%
us.groupby('Category', as_index=False)['Profit'].sum()
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
us['Profit'].mean()
# Out:
# 28.65689630778467

# %%
us.groupby('Category', as_index=False)['Profit', 'Sales'].sum()
# Out:
# <ipython-input-78-ed8be229a00a>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   us.groupby('Category', as_index=False)['Profit', 'Sales'].sum()
#           Category       Profit        Sales
# 0        Furniture   18451.2728  741999.7953
# 1  Office Supplies  122490.8008  719047.0320
# 2       Technology  145454.9481  836154.0330

# %%
us['Profit'].sum()
# Out:
# 286397.0217

# %%
us.groupby("Region", as_index=False)['Profit'].sum()
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
us_region_profit = us.groupby('Region', as_index=False)['Profit'].sum()
sns.set_color_codes(palette="deep")
sns.barplot(x='Region', y ='Profit', data=us_region_profit)
plt.show()

# %%
us_cat_region_profit = us.groupby(['Category','Region'], as_index=False)['Profit'].sum()
sns.barplot(x='Region', y ='Profit', hue='Category', data=us_cat_region_profit)
plt.show()
#furniture losing us money in the central region
#low profit margins in the south
#the company needs to invest more in technology

# %% [markdown]
# An alternative to the bar chart can be a pivot table:

# %%
pd.pivot_table(data=us_cat_region_profit,
              values='Profit',
               index='Category',
               columns = 'Region',
               aggfunc = ['sum','min']
               )
# Out:
#                         sum                                             min  \
# Region              Central        East       South        West     Central
# Category
# Furniture        -2871.0494   3046.1658   6771.2061  11504.9503  -2871.0494
# Office Supplies   8879.9799  41014.5791  19986.3928  52609.8490   8879.9799
# Technology       33697.4320  47462.0351  19991.8314  44303.6496  33697.4320
#
#
# Region                 East       South        West
# Category
# Furniture         3046.1658   6771.2061  11504.9503
# Office Supplies  41014.5791  19986.3928  52609.8490
# Technology       47462.0351  19991.8314  44303.6496

# %%
us_cntr_furn = us[(us['Category']=='Furniture') & (us['Region']=='Central')]
#us['Category']=='Furniture'
#us['Region']=='Central')]
#AND & in pandas
#OR |

us_cntr_furn
# Out:
#              Order ID  Order Date        Country   Region         State  \
# 14     US-2019-105417  07/01/2019  United States  Central         Texas
# 44     US-2019-167927  20/01/2019  United States  Central      Michigan
# 45     US-2019-167927  20/01/2019  United States  Central      Michigan
# 68     US-2019-167997  26/01/2019  United States  Central  South Dakota
# 100    US-2019-168368  11/02/2019  United States  Central      Missouri
# ...               ...         ...            ...      ...           ...
# 10071  US-2022-146164  22/12/2022  United States  Central     Minnesota
# 10152  US-2022-136539  28/12/2022  United States  Central         Texas
# 10154  US-2022-163860  28/12/2022  United States  Central      Illinois
# 10156  US-2022-163860  28/12/2022  United States  Central      Illinois
# 10157  US-2022-163860  28/12/2022  United States  Central      Illinois
#
#              City   Category Sub-Category  \
# 14     Huntsville  Furniture  Furnishings
# ...

# %%
us_cntr_furn.shape#method that allows to know rows and columns
# Out:
# (481, 14)

# %%
sns.histplot(data=us_cntr_furn, x= 'Profit', bins=35, kde=True)#to show a distribution of single variable, x=variable, bins = how many bucket we want to break the x axis, kde = smoothness of kernel estimate density
plt.show()

# %%
#peak of distribution is to the left of 0 so a concern
#so problematic for profit

# %%
us_cntr_furn['Profit'].sum()
# Out:
# -2871.0494

# %%
#losing -2871 dollars

# %%
us_cntr_furn.groupby(['Sub-Category'],as_index=False)['Profit'].sum()
# Out:
#   Sub-Category     Profit
# 0    Bookcases -1997.9043
# 1       Chairs  6592.7221
# 2  Furnishings -3906.2168
# 3       Tables -3559.6504

# %%
sns.boxplot(data=us_cntr_furn, x='Profit', y = 'Sub-Category')
plt.show()
#when left of zero then there is a problem

# %%
us_cntr_furn.groupby(['Sub-Category'],as_index=False)['Discount'].mean()
# Out:
#   Sub-Category  Discount
# 0    Bookcases  0.232800
# 1       Chairs  0.192857
# 2  Furnishings  0.403902
# 3       Tables  0.262500

# %%
us_profit_dscnt = us_cntr_furn.groupby(['Sub-Category'], as_index=False).agg(
    profit_sum = ('Profit','sum'),
    discount_avg=('Discount','mean')
)
us_profit_dscnt
# Out:
#   Sub-Category  profit_sum  discount_avg
# 0    Bookcases  -1997.9043      0.232800
# 1       Chairs   6592.7221      0.192857
# 2  Furnishings  -3906.2168      0.403902
# 3       Tables  -3559.6504      0.262500

# %%
sns.scatterplot(data=us_profit_dscnt, x='profit_sum', y='discount_avg',hue = 'Sub-Category',s = 100)
plt.show()

# %%
#profits fall as discounts increases

# %%
sns.lineplot

# %% [markdown]
# #Conclusions

# %%
df = pd.read_csv('https://raw.githubusercontent.com/boolean-data-analytics/data/main/Superstore%20Data%20S.csv')
df.head()
# Out:
#          Order ID  Order Date        Country   Region         State  \
# 0  US-2019-103800  03/01/2019  United States  Central         Texas
# 1  US-2019-112326  04/01/2019  United States  Central      Illinois
# 2  US-2019-112326  04/01/2019  United States  Central      Illinois
# 3  US-2019-112326  04/01/2019  United States  Central      Illinois
# 4  US-2019-141817  05/01/2019  United States     East  Pennsylvania
#
#            City         Category Sub-Category  \
# 0       Houston  Office Supplies        Paper
# 1    Naperville  Office Supplies      Binders
# 2    Naperville  Office Supplies       Labels
# 3    Naperville  Office Supplies      Storage
# 4  Philadelphia  Office Supplies          Art
#
#                                         Product Name  Customer Name  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Darren Powers         2
# 1         GBC Standard Plastic Binding Systems Combs  Phillina Ober         2
# ...
